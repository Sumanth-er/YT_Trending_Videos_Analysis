# %% [raw]
# pwd

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/satya/Desktop/PFSD_project/dataset/INvideos.csv', encoding="ISO-8859-1")

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  kzwfHumJyYc      17.14.11
# 1  zUZ1z7FwLc8      17.14.11
# 2  10L1hZ9qa58      17.14.11
# 3  N1vE8iiEg64      17.14.11
# 4  kJzGH0PVQHQ      17.14.11
#
#                                                title    channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...  Lokdhun Punjabi
# 1  à¤ªà¥à¤°à¤¿à¤¯à¤¡à¥à¤¸ à¤à¥ à¤¸à¤®à¤¯, à¤ª...          HJ NEWS
# 2  Stylish Star Allu Arjun @ ChaySam Wedding Rece...             TFPC
# 3                     Eruma Saani | Tamil vs English      Eruma Saani
# 4  why Samantha became EMOTIONAL @ Samantha naga ...       Filmylooks
#
#    category_id              publish_time  \
# 0            1  2017-11-12T12:20:39.000Z
# 1           25  2017-11-13T05:43:56.000Z
# 2           24  2017-11-12T15:48:08.000Z
# 3           23  2017-11-12T07:08:48.000Z
# 4           24  2017-11-13T01:14:16.000Z
#
#                                                 tags    views  likes  \
# ...

# %%
df.shape
# Out:
# (37352, 16)

# %%
import numpy as np

# %%
df.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  37352.000000  3.735200e+04  3.735200e+04  3.735200e+04    37352.00000
# mean      21.576596  1.060478e+06  2.708272e+04  1.665082e+03     2676.99743
# std        6.556593  3.184932e+06  9.714510e+04  1.607617e+04    14868.31713
# min        1.000000  4.024000e+03  0.000000e+00  0.000000e+00        0.00000
# 25%       23.000000  1.239155e+05  8.640000e+02  1.080000e+02       81.00000
# 50%       24.000000  3.045860e+05  3.069000e+03  3.260000e+02      329.00000
# 75%       24.000000  7.992912e+05  1.377425e+04  1.019250e+03     1285.00000
# max       43.000000  1.254322e+08  2.912710e+06  1.545017e+06   827755.00000

# %%
df['log_views']=np.log(df['views'])
df['log_likes']=np.log(df['likes'])
# Out:
# C:\Users\satya\anaconda3\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
from bokeh.plotting import figure,output_file, show
from bokeh.models import ColumnDataSource
from bokeh.models.tools import HoverTool

# %%
fig=figure(tooltips=TOOLTIPS)
p=fig.circle(x='likes',y='views',source=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18132/3318821281.py in <module>
# ----> 1 fig=figure(tooltips=TOOLTIPS)
#       2 p=fig.circle(x='likes',y='views',source=df)
#
# NameError: name 'TOOLTIPS' is not defined

# %%
#tooltips
TOOLTIPS = [
    ("Title","@title"),
    ("Channel","@channel_title"),
    ("Views","@views"),
]
fig = figure(tooltips=TOOLTIPS)
p = fig.circle(x='log_likes', y='log_views', source=df)

fig.xaxis.axis_label = 'Likes'
fig.yaxis.axis_label = 'views'
glyph = p.glyph
glyph.size = 10
glyph.fill_alpha = 0.2
glyph.fill_color = "#ADD8E6"
glyph.line_color = "grey"
glyph.line_dash = [6,3]
glyph.line_width = 2

# %%
show(fig)

# %%
df.groupby('category_id').count()
# Out:
#              video_id  trending_date  title  channel_title  publish_time  \
# category_id
# 1                2060           2060   2060           2060          2060
# 2                 353            353    353            353           353
# 10               3731           3731   3731           3731          3731
# 15                369            369    369            369           369
# 17               2787           2787   2787           2787          2787
# 19                392            392    392            392           392
# 20               1344           1344   1344           1344          1344
# 22               4105           4105   4105           4105          4105
# 23               3773           3773   3773           3773          3773
# 24              13451          13451  13451          13451         13451
# 25               4159           4159   4159           4159          4159
# 26               2007           2007   2007           2007          2007
# ...

# %%
entertatinment = df[df['category_id'] == 24 ]

# %%
entertatinment.sort_values('views', ascending=False)
# Out:
#           video_id trending_date  \
# 5900   FlsCjmMhFmw      17.13.12
# 5623   FlsCjmMhFmw      17.12.12
# 5398   FlsCjmMhFmw      17.11.12
# 5197   FlsCjmMhFmw      17.10.12
# 4699   6ZfuNTqbHE8      17.07.12
# ...            ...           ...
# 19937  wuF9_Jy7OfA      18.23.02
# 26046  yWp7YrLjoSQ      18.26.03
# 22721  s029voQMRzU      18.09.03
# 20505  MTtFpn9C7Q4      18.26.02
# 34625  bz91MAdY6FQ      18.14.05
#
#                                                    title  \
# 5900   YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# 5623   YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# 5398   YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# 5197   YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# 4699   Marvel Studios' Avengers: Infinity War Officia...
# ...                                                  ...
# 19937  Marijuana Stocks Technical Analysis Chart 2/22...
# 26046  Debbie Lynch-White de ''UnitÃ© 9'' incarne ''L...
# ...

# %%
entertatinment.views.dtype

# %%
entertatinment.describe()

# %%
pd.options.display.float_format = '{:,f}'.format
entertatinment[{'views','likes'}].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6452/1613318607.py in <module>
#       1 pd.options.display.float_format = '{:,f}'.format
# ----> 2 entertatinment[{'views','likes'}].describe()
#
# NameError: name 'entertatinment' is not defined

# %%
show(fig.df['category_id'] == 24)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15656/2320434560.py in <module>
# ----> 1 show(fig.df['category_id'] == 24)
#
# ~\anaconda3\lib\site-packages\bokeh\core\has_props.py in __getattr__(self, name)
#     262             return super().__getattr__(name)
#     263
# --> 264         self._raise_attribute_error_with_matches(name, properties)
#     265
#     266     def _raise_attribute_error_with_matches(self, name: str, properties: Iterable[str]) -> NoReturn:
#
# ~\anaconda3\lib\site-packages\bokeh\core\has_props.py in _raise_attribute_error_with_matches(self, name, properties)
#     270             matches, text = sorted(properties), "possible"
#     271
# --> 272         raise AttributeError(f"unexpected attribute {name!r} to {self.__class__.__name__}, {text} attributes are {nice_join(matches)}")
#     273
# ...
